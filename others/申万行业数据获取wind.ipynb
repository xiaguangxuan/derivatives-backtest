# %%
# import pandas as pd
# # import akshare as ak
# import numpy as np
# from tqdm import tqdm
# from WindPy import *
# w.start()
# Out:
# Welcome to use Wind Quant API for Python (WindPy)!
#
# COPYRIGHT (C) 2020 WIND INFORMATION CO., LTD. ALL RIGHTS RESERVED.
# IN NO CIRCUMSTANCE SHALL WIND BE RESPONSIBLE FOR ANY DAMAGES OR LOSSES CAUSED BY USING WIND QUANT API FOR Python.
# .ErrorCode=0
# .Data=[OK!]

# %% [markdown]
# ### Part 1 数据获取

# %%
# shangzheng = pd.read_csv('./data/上证A股.csv', encoding = 'gbk').drop(columns = 'Unnamed: 9')
# sz = pd.read_csv('./data/深圳A股.csv', encoding = 'gbk').drop(columns = 'Unnamed: 9')
# bz = pd.read_csv('./data/北证A股.csv', encoding = 'gbk').drop(columns = 'Unnamed: 9')

# %%
# shangzheng.to_csv('./data/全部A股weekly.csv', mode='a', index=False, header=True)
# sz.to_csv('./data/全部A股weekly.csv', mode='a', index=False, header=False)
# bz.to_csv('./data/全部A股weekly.csv', mode='a', index=False, header=False)

# %%
# data = pd.read_csv('./data/全部A股weekly.csv')

# %%
# index_list2 = "CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI".split(',')
# code_list2 = set()

# try:
#     for index_code in index_list2:
#         pool_information = pd.read_excel('./data/中信行业成分进出记录.xlsx', sheet_name = index_code)
#         code_list1 = code_list1.union(set(pool_information['tradecode']))
#         print(len(code_list1))

# except:

#     writer2 = pd.ExcelWriter('./data/中信行业成分进出记录.xlsx')

#     for index_code in index_list2:
#         pool_information = w.wset("indexhistory", "startdate=1900-06-01;enddate=2023-09-08;windcode=" + index_code + ";field=tradeDate,tradeCode,tradeName,tradeStatus", usedf=True)[1]
#         code_list2 = code_list2.union(set(pool_information['tradecode']))
#         pool_information.to_excel(writer2, sheet_name = index_code, index = False)
#         print(len(code_list2))

#     writer2.save()
# Out:
# 101
# 149
# 304
# 544
# 625
# 1138
# 1308
# 1418
# 1588
# 2248
# 2505
# 2603
# 2824
# 2958
# 3015
# 3096
# 3223
# 3672
# 3807
# 3902
# 3944
# 4003
# 4091
# 4203
# 4619
# 4758
# 5031
# 5117
# 5122
# 5122

# %%
# code_list = list(set(code_list2) - set(data['代码']))

# %%
# # np.save('./data/A股历史股票代码.npy', np.array(list(code_list)))
# # code_list = np.load('./data/A股历史股票代码.npy', allow_pickle = 1).tolist()
# df = pd.DataFrame()
# for code in code_list:
#     temp = w.wsd(code, "open,high,low,close,pct_chg", "2023-07-28", "2023-08-27", "Period=W;Fill=Previous", usedf=True)[1]
#     temp['代码'] = code
#     df = pd.concat([df, temp])
#     print(code)
# # df.to_csv('./data/A股行情数据.csv')

# %%
# data
# Out:
#                 代码    简称          日期    开盘价(元)    最高价(元)   最低价(元)   收盘价(元)  \
# 0        600000.SH  浦发银行  2009-01-09   36.9824   39.9662  36.5444  38.5701
# 1        600000.SH  浦发银行  2009-01-16   38.5701   44.0723  37.7763  42.7584
# 2        600000.SH  浦发银行  2009-01-23   43.3880   46.3991  43.1963  45.6874
# 3        600000.SH  浦发银行  2009-02-06   45.9885   48.6712  44.4282  48.0689
# 4        600000.SH  浦发银行  2009-02-13   49.2734   49.8756  45.4410  47.6310
# ...            ...   ...         ...       ...       ...      ...      ...
# 2295486  873593.BJ  鼎智科技  2023-07-28  102.1909  105.2671  88.4040  89.2216
# 2295487  873593.BJ  鼎智科技  2023-08-04   89.9267   99.1248  86.1555  97.4998
# 2295488  873593.BJ  鼎智科技  2023-08-11   97.6021  101.3835  89.6099  92.9519
# 2295489  873593.BJ  鼎智科技  2023-08-18   91.5211   95.2208  82.1697  83.8969
# 2295490  873593.BJ  鼎智科技  2023-08-25   81.8222   85.5321  72.5730  72.5730
#
#               成交金额(元)   涨跌幅(%)
# 0        4.564774e+09   6.3396
# ...

# %%
# open = w.wsd(code_list, "open", "2009-01-01", "2023-08-25", "Period=W;PriceAdj=B", usedf=True)[1]
# high = w.wsd(code_list, "high", "2009-01-01", "2023-08-25", "Period=W;PriceAdj=B", usedf=True)[1]
# low = w.wsd(code_list, "low", "2009-01-01", "2023-08-25", "Period=W;PriceAdj=B", usedf=True)[1]
# close = w.wsd(code_list, "close", "2009-01-01", "2023-08-25", "Period=W;PriceAdj=B", usedf=True)[1]
# pct_chg = w.wsd(code_list, "pct_chg", "2009-01-01", "2023-08-25", "Period=W;PriceAdj=B", usedf=True)[1]
# value = w.wsd(code_list, "amt", "2009-01-01", "2023-08-25", "Period=W;PriceAdj=B", usedf=True)[1]

# %%
# name_list = w.wss(code_list, "sec_name", "", usedf=True)[1]

# %%
# open_df = pd.DataFrame()

# for i in open.columns:
#     temp = open[[i]].dropna()
#     temp.columns = ['开盘价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = 
#     open_df = pd.concat([open_df, temp], axis = 0)

# close_df = pd.DataFrame()

# for i in close.columns:
#     temp = close[[i]].loc[open[i].dropna().index]
#     temp.columns = ['收盘价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i]
#     close_df = pd.concat([close_df, temp], axis = 0)

# high_df = pd.DataFrame()

# for i in high.columns:
#     temp = high[[i]].dropna()
#     temp.columns = ['最高价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i]
#     high_df = pd.concat([high_df, temp], axis = 0)

# low_df = pd.DataFrame()

# for i in low.columns:
#     temp = low[[i]].dropna()
#     temp.columns = ['最低价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i]
#     low_df = pd.concat([low_df, temp], axis = 0)

# value_df = pd.DataFrame()

# for i in value.columns:
#     temp = value[[i]].reindex(open[i].dropna().index).fillna(0)
#     temp.columns = ['成交金额(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i].values[0]
#     value_df = pd.concat([value_df, temp], axis = 0)

# pct_df = pd.DataFrame()

# for i in pct_chg.columns:
#     temp = pct_chg[[i]].loc[open[i].dropna().index]
#     temp.columns = ['涨跌幅(%)']
#     temp['代码'] = i
#     temp['简称'] = name_list.loc[i].values[0]
#     pct_df = pd.concat([pct_df, temp], axis = 0)

# add_data = pd.concat([open_df, close_df, high_df, low_df, value_df, pct_df], axis = 1)
# add_data = add_data.reset_index()
# add_data.columns = ['日期', '开盘价(元)', '收盘价(元)', '最高价(元)', '最低价(元)', '成交金额(元)', '涨跌幅(%)', '代码', '简称']
# add_data = add_data[['代码', '简称', '日期', '开盘价(元)', '最高价(元)', '最低价(元)', '收盘价(元)', '成交金额(元)', '涨跌幅(%)']]

# %%
# add_data = pd.concat([open_df, close_df, high_df, low_df, value_df, pct_df], axis = 1)
# add_data = add_data.reset_index()
# add_data.columns = ['日期', '开盘价(元)', '收盘价(元)', '最高价(元)', '最低价(元)', '成交金额(元)', '涨跌幅(%)', '代码', '简称']
# add_data = add_data[['代码', '简称', '日期', '开盘价(元)', '最高价(元)', '最低价(元)', '收盘价(元)', '成交金额(元)', '涨跌幅(%)']]

# %%
# add_data
# Out:
#               代码       简称          日期     开盘价(元)     最高价(元)     最低价(元)  \
# 0      300309.SZ  吉艾退(退市)  2012-04-13  30.000000  31.300000  29.610000
# 1      300309.SZ  吉艾退(退市)  2012-04-20  29.300000  30.290000  28.670000
# 2      300309.SZ  吉艾退(退市)  2012-04-27  29.500000  29.500000  27.710000
# 3      300309.SZ  吉艾退(退市)  2012-05-04  28.310000  29.390000  28.300000
# 4      300309.SZ  吉艾退(退市)  2012-05-11  29.100000  30.520000  28.320000
# ...          ...      ...         ...        ...        ...        ...
# 87654  000606.SZ  顺利退(退市)  2023-06-09   5.927604   5.927604   5.927604
# 87655  000606.SZ  顺利退(退市)  2023-06-16   5.927604   5.927604   1.159749
# 87656  000606.SZ  顺利退(退市)  2023-06-21   1.610762   1.804053   1.546332
# 87657  000606.SZ  顺利退(退市)  2023-06-30   1.675192   1.739623   1.417471
# 87658  000606.SZ  顺利退(退市)  2023-07-07   1.546332   1.868484   1.481901
#
#           收盘价(元)      成交金额(元)     涨跌幅(%)
# 0      29.920000  818204420.7  -2.857143
# ...

# %%
# add_data.to_csv('./data/全部A股weekly.csv', mode='a', index=False, header=False)

# %% [markdown]
# ### Part 2 增量更新

# %% [markdown]
# #### 2.1 更新股票池

# %% [markdown]
# #### 申万成分更新

# %%
# index_list1 = "801010.SI,801030.SI,801040.SI,801050.SI,801080.SI,801110.SI,801120.SI,801130.SI,801140.SI,801150.SI,801160.SI,801170.SI,801180.SI,801200.SI,801210.SI,801230.SI,801710.SI,801720.SI,801730.SI,801740.SI,801750.SI,801760.SI,801770.SI,801780.SI,801790.SI,801880.SI,801890.SI,801950.SI,801960.SI,801970.SI,801980.SI".split(',')
# code_list1 = set()

# try:
#     for index_code in index_list1:
#         pool_information = pd.read_excel('./data/申万行业成分进出记录.xlsx', sheet_name = index_code)
#         code_list1 = code_list1.union(set(pool_information['tradecode']))
#         print(len(code_list1))

# except:

#     writer2 = pd.ExcelWriter('./data/申万行业成分进出记录.xlsx')

#     for index_code in tqdm(index_list1):
#         pool_information = w.wset("indexhistory", "startdate=1900-06-01;enddate=2023-09-22;windcode=" + index_code + ";field=tradeDate,tradeCode,tradeName,tradeStatus", usedf=True)[1]
#         code_list1 = code_list1.union(set(pool_information['tradecode']))
#         pool_information.to_excel(writer2, sheet_name = index_code, index = False)
        

#     writer2.save()
# Out:
# 100%|██████████| 31/31 [00:30<00:00,  1.03it/s]

# %% [markdown]
# #### 中信成分更新

# %%
# index_list2 = "CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI".split(',')
# code_list2 = set()

# try:
#     for index_code in index_list2:
#         pool_information = pd.read_excel('./data/中信行业成分进出记录.xlsx', sheet_name = index_code)
#         code_list2 = code_list2.union(set(pool_information['tradecode']))
#         print(len(code_list2))

# except:

#     writer2 = pd.ExcelWriter('./data/中信行业成分进出记录.xlsx')

#     for index_code in tqdm(index_list2):
#         pool_information = w.wset("indexhistory", "startdate=1900-06-01;enddate=2023-09-22;windcode=" + index_code + ";field=tradeDate,tradeCode,tradeName,tradeStatus", usedf=True)[1]
#         code_list2 = code_list2.union(set(pool_information['tradecode']))
#         pool_information.to_excel(writer2, sheet_name = index_code, index = False)


#     writer2.save()
# Out:
# 100%|██████████| 30/30 [00:35<00:00,  1.19s/it]

# %% [markdown]
# #### 2.2 更新股票数据

# %%
# code_list = list(code_list1.union(code_list2))

# %%
# open = w.wsd(code_list, "open", "2023-09-16", "2023-09-22", "Period=W;PriceAdj=B", usedf=True)[1]
# high = w.wsd(code_list, "high", "2023-09-16", "2023-09-22", "Period=W;PriceAdj=B", usedf=True)[1]
# low = w.wsd(code_list, "low", "2023-09-16", "2023-09-22", "Period=W;PriceAdj=B", usedf=True)[1]
# close = w.wsd(code_list, "close", "2023-09-16", "2023-09-22", "Period=W;PriceAdj=B", usedf=True)[1]
# pct_chg = w.wsd(code_list, "pct_chg", "2023-09-16", "2023-09-22", "Period=W;PriceAdj=B", usedf=True)[1]
# value = w.wsd(code_list, "amt", "2023-09-16", "2023-09-22", "Period=W;PriceAdj=B", usedf=True)[1]
# name_list = w.wss(code_list, "sec_name", "", usedf=True)[1]

# def change_type(df):
#     df.columns = [pd.to_datetime('2023-09-22')]
#     return df.T

# open = change_type(open)
# high = change_type(high)
# low = change_type(low)
# close = change_type(close)
# pct_chg = change_type(pct_chg)
# value = change_type(value)

# %%
# open_df = pd.DataFrame()

# for i in open.columns:
#     temp = open[[i]].dropna()
#     temp.columns = ['开盘价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = 
#     open_df = pd.concat([open_df, temp], axis = 0)

# close_df = pd.DataFrame()

# for i in close.columns:
#     temp = close[[i]].loc[open[i].dropna().index]
#     temp.columns = ['收盘价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i]
#     close_df = pd.concat([close_df, temp], axis = 0)

# high_df = pd.DataFrame()

# for i in high.columns:
#     temp = high[[i]].dropna()
#     temp.columns = ['最高价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i]
#     high_df = pd.concat([high_df, temp], axis = 0)

# low_df = pd.DataFrame()

# for i in low.columns:
#     temp = low[[i]].dropna()
#     temp.columns = ['最低价(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i]
#     low_df = pd.concat([low_df, temp], axis = 0)

# value_df = pd.DataFrame()

# for i in value.columns:
#     temp = value[[i]].reindex(open[i].dropna().index).fillna(0)
#     temp.columns = ['成交金额(元)']
#     # temp['代码'] = i
#     # temp['简称'] = name_list.loc[i].values[0]
#     value_df = pd.concat([value_df, temp], axis = 0)

# pct_df = pd.DataFrame()

# for i in pct_chg.columns:
#     temp = pct_chg[[i]].loc[open[i].dropna().index]
#     temp.columns = ['涨跌幅(%)']
#     temp['代码'] = i
#     temp['简称'] = name_list.loc[i].values[0]
#     pct_df = pd.concat([pct_df, temp], axis = 0)

# add_data = pd.concat([open_df, close_df, high_df, low_df, value_df, pct_df], axis = 1)
# add_data = add_data.reset_index()
# add_data.columns = ['日期', '开盘价(元)', '收盘价(元)', '最高价(元)', '最低价(元)', '成交金额(元)', '涨跌幅(%)', '代码', '简称']
# add_data = add_data[['代码', '简称', '日期', '开盘价(元)', '最高价(元)', '最低价(元)', '收盘价(元)', '成交金额(元)', '涨跌幅(%)']]

# %%
# add_data
# Out:
#              代码    简称         日期      开盘价(元)      最高价(元)      最低价(元)  \
# 0     000783.SZ  长江证券 2023-09-22   35.545875   36.335784   35.363589
# 1     600791.SH  京能置业 2023-09-22   33.556611   33.777379   32.820721
# 2     603858.SH  步长制药 2023-09-22   39.402476   39.687842   38.392719
# 3     603387.SH  基蛋生物 2023-09-22   46.591294   47.340083   45.925704
# 4     603699.SH  纽威股份 2023-09-22   19.116781   19.425531   18.409228
# ...         ...   ...        ...         ...         ...         ...
# 5024  603258.SH  电魂网络 2023-09-22   31.852768   33.577528   30.614479
# 5025  600383.SH  金地集团 2023-09-22  136.323441  136.323441  131.791914
# 5026  688112.SH  鼎阳科技 2023-09-22   73.500277   73.804689   68.690568
# 5027  688448.SH  磁谷科技 2023-09-22   31.030000   33.900000   30.050000
# 5028  688508.SH   芯朋微 2023-09-22   59.517666   59.517666   55.885562
#
#           收盘价(元)       成交金额(元)    涨跌幅(%)
# 0      36.214259  7.175570e+08  1.706485
# 1      33.630200  1.416802e+08 -0.218341
# ...

# %%
# add_data.to_csv('./data/全部A股weekly.csv', mode='a', index=False, header=False)

# %% [markdown]
# ### Part 3 绘图

# %% [markdown]
# #### 3.1 计算 Hindenburg Index

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# from tqdm import tqdm
# import akshare as ak
# from dateutil import relativedelta
# from WindPy import *
# w.start()
# import datetime
# plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
# mpl.rcParams['axes.unicode_minus']=False
# import warnings
# warnings.filterwarnings('ignore')
# import sys
# # 加载当前路径
# sys.path.append('.')

# ##################### 读取股票数据 ####################
# data = pd.read_csv('./data/全部A股weekly.csv')
# data = data[data['日期'] > '2010-01-01']
# timestamp = sorted(list(set(data['日期'])))
# data = data.set_index('日期')
# # data['年月'] = data['日期'].apply(lambda x: x[:-3].replace('-', ''))
# value = data.groupby('代码')[['成交金额(元)']].rolling(4).mean()
# high = data.groupby('代码')[['最高价(元)']].rolling(4).max()
# low = data.groupby('代码')[['最低价(元)']].rolling(4).min()
# data = high.join(low)
# highest = data['最高价(元)'].groupby('代码').rolling(52, min_periods = 12).max()
# lowest = data['最低价(元)'].groupby('代码').rolling(52, min_periods = 12).min()
# data = data.reset_index()
# data['12月最高'] = highest.values
# data['12月最低'] = lowest.values

# ################## 获得每一天对应的样本股数据 ######################
# # Wind 下载数据
# # pool_information = pd.read_excel('./data/000905.SH-成分进出记录-20230720.xlsx').sort_values('日期', ignore_index = 1)
# # 调用 Wind 接口

# # index_list = "801010.SI,801030.SI,801040.SI,801050.SI,801080.SI,801110.SI,801120.SI,801130.SI,801140.SI,801150.SI,801160.SI,801170.SI,801180.SI,801200.SI,801210.SI,801230.SI,801710.SI,801720.SI,801730.SI,801740.SI,801750.SI,801760.SI,801770.SI,801780.SI,801790.SI,801880.SI,801890.SI,801950.SI,801960.SI,801970.SI,801980.SI".split(',')
# # index_name = w.wss("801010.SI,801030.SI,801040.SI,801050.SI,801080.SI,801110.SI,801120.SI,801130.SI,801140.SI,801150.SI,801160.SI,801170.SI,801180.SI,801200.SI,801210.SI,801230.SI,801710.SI,801720.SI,801730.SI,801740.SI,801750.SI,801760.SI,801770.SI,801780.SI,801790.SI,801880.SI,801890.SI,801950.SI,801960.SI,801970.SI,801980.SI", "sec_name", "", usedf=True)[1]

# index_list = "CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI".split(',')
# index_name = w.wss("CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI", "sec_name", "", usedf=True)[1]
# index_time = w.wss("CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI", "ipo_date", "", usedf=True)[1]
# trade_date = w.tdays('2010-01-01', "2023-08-25", "Period=W", usedf=0).Data[0]
# Database_Hindenburg = pd.DataFrame()
# for index_code in tqdm(index_list):
#     # pool_information = w.wset("indexhistory", "startdate=1900-06-01;enddate=2023-08-23;windcode=" + index_code + ";field=tradeDate,tradeCode,tradeName,tradeStatus", usedf=True)[1]
#     pool_information = pd.read_excel('./data/中证行业成分进出记录.xlsx', sheet_name = index_code)
#     pool_information.columns = ['日期', '代码', '简称', '纳入/剔除']
#     pool_information = pool_information.sort_values('日期', ignore_index = 1)
#     code_list = sorted(list(set(pool_information['代码'])))
#     # 适应 Akshare 数据库 
#     pool_information['代码'] = pool_information['代码']

#     pool_in_information = pool_information[pool_information['纳入/剔除'] == '纳入']
#     pool_out_information = pool_information[pool_information['纳入/剔除'] == '剔除']

#     add_in = dict()
#     move_out = dict()

#     for name, group in pool_in_information.groupby('日期')['代码']:
#         add_in[name] = set(group)

#     for name, group in pool_out_information.groupby('日期')['代码']:
#         move_out[name] = set(group)

#     t = list(add_in.keys()) + list(move_out.keys())
#     t = sorted(list(set(t)))
#     population_pool = {t[0]: list(add_in[t[0]])}
#     flag = 0
#     for i in range(1, len(t)):
#         if (t[i] in add_in) & (t[i] in move_out):
#             population_pool[t[i]] = list((set(population_pool[t[i - 1]]) | add_in[t[i]]) - move_out[t[i]])
#         elif t[i] in add_in:
#             population_pool[t[i]] = list(set(population_pool[t[i - 1]]) | add_in[t[i]])
#         elif t[i] in move_out:
#             population_pool[t[i]] = list(set(population_pool[t[i - 1]]) - move_out[t[i]])
#         if (flag == 0) & (len(population_pool[t[i]]) > 10):
#             flag = max(t[i].strftime('%Y-%m-%d'), str(index_time.loc[index_code].values[0]), '2010-01-01')
#             # flag = max(t[i].strftime('%Y-%m-%d'), '2010-01-01')

#     # 如果没有更新到今天
#     if datetime.date.today().strftime('%Y-%m-%d') != t[-1]:
#         # 给今天赋予一个空值，后期填补至今天
#         population_pool[datetime.date.today().strftime('%Y-%m-%d')] = np.nan

#     population_pool_series = pd.Series(population_pool)
#     population_pool_series.index = pd.DatetimeIndex(population_pool_series.index)

#     # 获得每个交易日的信息
#     # last_trade_date = w.tdays(flag, "2023-08-23", "Period=W", usedf=0).Data[0]
#     # last_trade_date = timestamp[timestamp.index(flag): '2023-07-31']

#     last_trade_date = [i for i in trade_date if i > datetime.datetime.strptime(flag, '%Y-%m-%d')]
#     last_trade_date = [t.strftime('%Y-%m-%d') for t in last_trade_date]
#     idx = population_pool_series.index
#     idx = idx.append(pd.DatetimeIndex(last_trade_date))
#     idx = idx.drop_duplicates()
#     population_pool_series = population_pool_series.reindex(idx)
#     population_pool_series = population_pool_series.sort_index()
#     # 更改日期，填补空值
#     population_pool_series = population_pool_series.ffill()
#     last_trade_date_datetime = pd.DatetimeIndex(last_trade_date)
#     # trade_month = [t.strftime('%Y-%m-%d') for t in last_trade_date]
#     HindenburgIndex = pd.Series()
#     for i in range(52, len(last_trade_date)):
#         value_month = value.loc[population_pool_series[last_trade_date[i]]].query('日期 == "' +  last_trade_date[i]  +  '"')
#         value_rank = value_month.rank(pct = True)
#         # 处于行业前 30%
#         fliter = value_rank[value_rank >= 0.7].dropna()
#         # 样本池子
#         sample_pool = fliter.index.droplevel(1)
        
#         sample_year_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] >= last_trade_date[i - 51]) & (data['日期'] <= last_trade_date[i])]
        
#         sample_month_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] >= last_trade_date[i - 3]) & (data['日期'] <= last_trade_date[i])]

#         sign1 = sample_month_data.groupby(['代码'])['最低价(元)'].min().values == sample_year_data.groupby(['代码'])['最低价(元)'].min().values
#         NewLowNum = np.sum(sign1)
#         # 可以对计算 max 的数据再次切片，剔除已经是 min 的标的
#         sign2 = sample_month_data.groupby(['代码'])['最高价(元)'].max().values == sample_year_data.groupby(['代码'])['最高价(元)'].max().values
#         NewHighNum = np.sum(sign2) - np.sum(sign1 & sign2)
        
#         HindenburgIndex[last_trade_date_datetime[i]] = (NewHighNum - NewLowNum) / len(sample_pool)
#         print(i)

#     # mkt = w.wsd(index_code, "close", flag, "2023-07-31", "Period=M;Fill=Previous", usedf=True)[1]
#     # ax = HindenburgIndex.plot(figsize = (15, 7), color = 'silver')
#     # ax1 = ax.twinx() 
#     # mkt.plot(ax = ax1)
#     # plt.legend(index_name.loc[index_code])

#     mkt = w.wsd(index_code, "close", last_trade_date[52], "2023-08-25", "Period=W;Fill=Previous", usedf=True)[1]
#     fig, ax = plt.subplots(figsize = (15, 7))
#     ax.fill_between(HindenburgIndex.index, 0, HindenburgIndex.values, facecolor = 'silver')
#     ax1 = ax.twinx() 
#     mkt.plot(ax = ax1)
#     ax.grid(axis = 'y', linestyle='--')
#     plt.legend(index_name.loc[index_code])

#     plt.savefig('./output/'+ str(index_name.loc[index_code].values[0]) + '.pdf')
#     plt.close()
#     Database_Hindenburg[index_code] = HindenburgIndex

# %% [markdown]
# #### 3.2 更新 Hindenburg Index

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# from tqdm import tqdm
# import akshare as ak
# from dateutil import relativedelta
# from WindPy import *
# w.start()
# import datetime
# plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
# mpl.rcParams['axes.unicode_minus']=False
# import warnings
# warnings.filterwarnings('ignore')
# import sys
# # 加载当前路径
# sys.path.append('.')

# ##################### 读取股票数据 ####################
# data = pd.read_csv('./data/全部A股weekly.csv')
# data = data[data['日期'] > '2022-01-01']
# timestamp = sorted(list(set(data['日期'])))
# data = data.set_index('日期')
# # data['年月'] = data['日期'].apply(lambda x: x[:-3].replace('-', ''))
# value = data.groupby('代码')[['成交金额(元)']].rolling(4).mean()
# high = data.groupby('代码')[['最高价(元)']].rolling(4).max()
# low = data.groupby('代码')[['最低价(元)']].rolling(4).min()
# data = high.join(low)
# highest = data['最高价(元)'].groupby('代码').rolling(52, min_periods = 12).max()
# lowest = data['最低价(元)'].groupby('代码').rolling(52, min_periods = 12).min()
# data = data.reset_index()
# data['12月最高'] = highest.values
# data['12月最低'] = lowest.values

# ################## 获得每一天对应的样本股数据 ######################
# # Wind 下载数据
# # pool_information = pd.read_excel('./data/000905.SH-成分进出记录-20230720.xlsx').sort_values('日期', ignore_index = 1)
# # 调用 Wind 接口

# index_list = "801010.SI,801030.SI,801040.SI,801050.SI,801080.SI,801110.SI,801120.SI,801130.SI,801140.SI,801150.SI,801160.SI,801170.SI,801180.SI,801200.SI,801210.SI,801230.SI,801710.SI,801720.SI,801730.SI,801740.SI,801750.SI,801760.SI,801770.SI,801780.SI,801790.SI,801880.SI,801890.SI,801950.SI,801960.SI,801970.SI,801980.SI".split(',')
# index_name = w.wss("801010.SI,801030.SI,801040.SI,801050.SI,801080.SI,801110.SI,801120.SI,801130.SI,801140.SI,801150.SI,801160.SI,801170.SI,801180.SI,801200.SI,801210.SI,801230.SI,801710.SI,801720.SI,801730.SI,801740.SI,801750.SI,801760.SI,801770.SI,801780.SI,801790.SI,801880.SI,801890.SI,801950.SI,801960.SI,801970.SI,801980.SI", "sec_name", "", usedf=True)[1]

# # index_list = "CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI".split(',')
# # index_name = w.wss("CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI", "sec_name", "", usedf=True)[1]
# # index_time = w.wss("CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI", "ipo_date", "", usedf=True)[1]
# trade_date = w.tdays('2023-08-26', "2023-09-15", "Period=W", usedf=0).Data[0]
# Database_Hindenburg = pd.read_csv('./data/申万一级行业兴登堡指数.csv', index_col = 0)
# Database_Hindenburg_update = pd.DataFrame()
# flag = pd.Series(0, index = index_list)
# for index_code in tqdm(index_list):
#     # pool_information = w.wset("indexhistory", "startdate=1900-06-01;enddate=2023-08-23;windcode=" + index_code + ";field=tradeDate,tradeCode,tradeName,tradeStatus", usedf=True)[1]
#     pool_information = pd.read_excel('./data/申万行业成分进出记录.xlsx', sheet_name = index_code)
#     pool_information.columns = ['日期', '代码', '简称', '纳入/剔除']
#     pool_information = pool_information.sort_values('日期', ignore_index = 1)
#     code_list = sorted(list(set(pool_information['代码'])))
#     # 适应 Akshare 数据库 
#     pool_information['代码'] = pool_information['代码']

#     pool_in_information = pool_information[pool_information['纳入/剔除'] == '纳入']
#     pool_out_information = pool_information[pool_information['纳入/剔除'] == '剔除']

#     add_in = dict()
#     move_out = dict()

#     for name, group in pool_in_information.groupby('日期')['代码']:
#         add_in[name] = set(group)

#     for name, group in pool_out_information.groupby('日期')['代码']:
#         move_out[name] = set(group)

#     t = list(add_in.keys()) + list(move_out.keys())
#     t = sorted(list(set(t)))
#     population_pool = {t[0]: list(add_in[t[0]])}
#     # flag = 0
#     for i in range(1, len(t)):
#         if (t[i] in add_in) & (t[i] in move_out):
#             population_pool[t[i]] = list((set(population_pool[t[i - 1]]) | add_in[t[i]]) - move_out[t[i]])
#         elif t[i] in add_in:
#             population_pool[t[i]] = list(set(population_pool[t[i - 1]]) | add_in[t[i]])
#         elif t[i] in move_out:
#             population_pool[t[i]] = list(set(population_pool[t[i - 1]]) - move_out[t[i]])
#         if (flag[index_code] == 0) & (len(population_pool[t[i]]) > 10):
#             # flag[index_code] = max(t[i].strftime('%Y-%m-%d'), str(index_time.loc[index_code].values[0]), '2010-01-01')
#             flag[index_code] = max(t[i].strftime('%Y-%m-%d'), '2010-01-01')

#     # 如果没有更新到今天
#     if datetime.date.today().strftime('%Y-%m-%d') != t[-1]:
#         # 给今天赋予一个空值，后期填补至今天
#         population_pool[datetime.date.today().strftime('%Y-%m-%d')] = np.nan

#     population_pool_series = pd.Series(population_pool)
#     population_pool_series.index = pd.DatetimeIndex(population_pool_series.index)

#     # 获得每个交易日的信息
#     # last_trade_date = w.tdays(flag, "2023-08-23", "Period=W", usedf=0).Data[0]
#     # last_trade_date = timestamp[timestamp.index(flag): '2023-07-31']

#     last_trade_date = [i for i in trade_date if i > datetime.datetime.strptime(flag[index_code], '%Y-%m-%d')]
#     last_trade_date = [t.strftime('%Y-%m-%d') for t in last_trade_date]
#     idx = population_pool_series.index
#     idx = idx.append(pd.DatetimeIndex(last_trade_date))
#     idx = idx.drop_duplicates()
#     population_pool_series = population_pool_series.reindex(idx)
#     population_pool_series = population_pool_series.sort_index()
#     # 更改日期，填补空值
#     population_pool_series = population_pool_series.ffill()
#     last_trade_date_datetime = pd.DatetimeIndex(last_trade_date)
#     # trade_month = [t.strftime('%Y-%m-%d') for t in last_trade_date]
#     HindenburgIndex = Database_Hindenburg[index_code]
#     for i in range(len(last_trade_date)):
#         value_month = value.loc[population_pool_series[last_trade_date[i]]].query('日期 == "' +  last_trade_date[i]  +  '"')
#         value_rank = value_month.rank(pct = True)
#         # 处于行业前 30%
#         fliter = value_rank[value_rank >= 0.7].dropna()
#         # 样本池子
#         sample_pool = fliter.index.droplevel(1)
        
#         # sample_year_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] >= last_trade_date[i - 51]) & (data['日期'] <= last_trade_date[i])]
#         sample_year_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] == last_trade_date[i])]
#         # sample_month_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] >= last_trade_date[i - 3]) & (data['日期'] <= last_trade_date[i])]

#         sign1 = sample_year_data['12月最低'].values == sample_year_data['最低价(元)'].values
#         NewLowNum = np.sum(sign1)
#         # 可以对计算 max 的数据再次切片，剔除已经是 min 的标的
#         sign2 = sample_year_data['12月最高'].values == sample_year_data['最高价(元)'].values
#         NewHighNum = np.sum(sign2) - np.sum(sign1 & sign2)
        
#         HindenburgIndex[last_trade_date_datetime[i]] = (NewHighNum - NewLowNum) / len(sample_pool)
#         # print(i)

#     # mkt = w.wsd(index_code, "close", flag, "2023-07-31", "Period=M;Fill=Previous", usedf=True)[1]
#     # ax = HindenburgIndex.plot(figsize = (15, 7), color = 'silver')
#     # ax1 = ax.twinx() 
#     # mkt.plot(ax = ax1)
#     # plt.legend(index_name.loc[index_code])

#     # mkt = w.wsd(index_code, "close", last_trade_date[0], "2023-09-08", "Period=W;Fill=Previous", usedf=True)[1]
#     # fig, ax = plt.subplots(figsize = (15, 7))
#     # ax.fill_between(HindenburgIndex.index, 0, HindenburgIndex.values, facecolor = 'silver')
#     # ax1 = ax.twinx() 
#     # mkt.plot(ax = ax1)
#     # ax.grid(axis = 'y', linestyle='--')
#     # plt.legend(index_name.loc[index_code])

#     # plt.savefig('./output/'+ str(index_name.loc[index_code].values[0]) + '.pdf')
#     # plt.close()
#     Database_Hindenburg_update[index_code] = HindenburgIndex
# Database_Hindenburg_update.index = pd.DatetimeIndex(Database_Hindenburg_update.index)
# for i in range(len(Database_Hindenburg_update)):
#     if sum(Database_Hindenburg_update.iloc[i] > 0.8) >= 5:
#         temp = Database_Hindenburg_update.iloc[i]
#         temp[temp > 0.8] = 0
#         Database_Hindenburg_update.iloc[i] = temp

# for index_code in tqdm(index_list):

#     mkt = w.wsd(index_code, "close", flag[index_code], "2023-09-15", "Period=W;Fill=Previous", usedf=True)[1]
#     mkt = mkt[52:]
#     fig, ax = plt.subplots(figsize = (15, 7))
#     ax.fill_between(Database_Hindenburg_update[index_code].index, 0, Database_Hindenburg_update[index_code].values, facecolor = 'silver')
#     ax1 = ax.twinx() 
#     mkt.plot(ax = ax1)
#     ax.grid(axis = 'y', linestyle='--')
#     plt.legend(index_name.loc[index_code])

#     plt.savefig('./output/'+ str(index_name.loc[index_code].values[0]) + '.pdf')
#     plt.close()
# Out:
# ...
# 100%|██████████| 31/31 [00:12<00:00,  2.54it/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from tqdm import tqdm
import akshare as ak
from dateutil import relativedelta
from WindPy import *
w.start()
import datetime
plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
mpl.rcParams['axes.unicode_minus']=False
import warnings
warnings.filterwarnings('ignore')
import sys
# 加载当前路径
sys.path.append('.')

##################### 读取股票数据 ####################
data = pd.read_csv('./data/全部A股weekly.csv')
data = data[data['日期'] > '2022-01-01']
timestamp = sorted(list(set(data['日期'])))
data = data.set_index('日期')
# data['年月'] = data['日期'].apply(lambda x: x[:-3].replace('-', ''))
value = data.groupby('代码')[['成交金额(元)']].rolling(4).mean()
high = data.groupby('代码')[['最高价(元)']].rolling(4).max()
low = data.groupby('代码')[['最低价(元)']].rolling(4).min()
data = high.join(low)
highest = data['最高价(元)'].groupby('代码').rolling(52, min_periods = 12).max()
lowest = data['最低价(元)'].groupby('代码').rolling(52, min_periods = 12).min()
data = data.reset_index()
data['12月最高'] = highest.values
data['12月最低'] = lowest.values

################## 获得每一天对应的样本股数据 ######################
# Wind 下载数据
# pool_information = pd.read_excel('./data/000905.SH-成分进出记录-20230720.xlsx').sort_values('日期', ignore_index = 1)
# 调用 Wind 接口

# index_list = "801010.SI,801030.SI,801040.SI,801050.SI,801080.SI,801110.SI,801120.SI,801130.SI,801140.SI,801150.SI,801160.SI,801170.SI,801180.SI,801200.SI,801210.SI,801230.SI,801710.SI,801720.SI,801730.SI,801740.SI,801750.SI,801760.SI,801770.SI,801780.SI,801790.SI,801880.SI,801890.SI,801950.SI,801960.SI,801970.SI,801980.SI".split(',')
# index_name = w.wss("801010.SI,801030.SI,801040.SI,801050.SI,801080.SI,801110.SI,801120.SI,801130.SI,801140.SI,801150.SI,801160.SI,801170.SI,801180.SI,801200.SI,801210.SI,801230.SI,801710.SI,801720.SI,801730.SI,801740.SI,801750.SI,801760.SI,801770.SI,801780.SI,801790.SI,801880.SI,801890.SI,801950.SI,801960.SI,801970.SI,801980.SI", "sec_name", "", usedf=True)[1]

index_list = "CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI".split(',')
index_name = w.wss("CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI", "sec_name", "", usedf=True)[1]
index_time = w.wss("CI005001.WI,CI005002.WI,CI005003.WI,CI005004.WI,CI005005.WI,CI005006.WI,CI005007.WI,CI005008.WI,CI005009.WI,CI005010.WI,CI005011.WI,CI005012.WI,CI005013.WI,CI005014.WI,CI005015.WI,CI005016.WI,CI005017.WI,CI005018.WI,CI005019.WI,CI005020.WI,CI005021.WI,CI005022.WI,CI005023.WI,CI005024.WI,CI005025.WI,CI005026.WI,CI005027.WI,CI005028.WI,CI005029.WI,CI005030.WI", "ipo_date", "", usedf=True)[1]
trade_date = w.tdays('2023-08-26', "2023-09-15", "Period=W", usedf=0).Data[0]
Database_Hindenburg = pd.read_csv('./data/中信一级行业兴登堡指数.csv', index_col = 0)
Database_Hindenburg_update = pd.DataFrame()
flag = pd.Series(0, index = index_list)
for index_code in tqdm(index_list):
    # pool_information = w.wset("indexhistory", "startdate=1900-06-01;enddate=2023-08-23;windcode=" + index_code + ";field=tradeDate,tradeCode,tradeName,tradeStatus", usedf=True)[1]
    pool_information = pd.read_excel('./data/中信行业成分进出记录.xlsx', sheet_name = index_code)
    pool_information.columns = ['日期', '代码', '简称', '纳入/剔除']
    pool_information = pool_information.sort_values('日期', ignore_index = 1)
    code_list = sorted(list(set(pool_information['代码'])))
    # 适应 Akshare 数据库 
    pool_information['代码'] = pool_information['代码']

    pool_in_information = pool_information[pool_information['纳入/剔除'] == '纳入']
    pool_out_information = pool_information[pool_information['纳入/剔除'] == '剔除']

    add_in = dict()
    move_out = dict()

    for name, group in pool_in_information.groupby('日期')['代码']:
        add_in[name] = set(group)

    for name, group in pool_out_information.groupby('日期')['代码']:
        move_out[name] = set(group)

    t = list(add_in.keys()) + list(move_out.keys())
    t = sorted(list(set(t)))
    population_pool = {t[0]: list(add_in[t[0]])}
    # flag = 0
    for i in range(1, len(t)):
        if (t[i] in add_in) & (t[i] in move_out):
            population_pool[t[i]] = list((set(population_pool[t[i - 1]]) | add_in[t[i]]) - move_out[t[i]])
        elif t[i] in add_in:
            population_pool[t[i]] = list(set(population_pool[t[i - 1]]) | add_in[t[i]])
        elif t[i] in move_out:
            population_pool[t[i]] = list(set(population_pool[t[i - 1]]) - move_out[t[i]])
        if (flag[index_code] == 0) & (len(population_pool[t[i]]) > 10):
            flag[index_code] = max(t[i].strftime('%Y-%m-%d'), str(index_time.loc[index_code].values[0]), '2010-01-01')
            # flag[index_code] = max(t[i].strftime('%Y-%m-%d'), '2010-01-01')

    # 如果没有更新到今天
    if datetime.date.today().strftime('%Y-%m-%d') != t[-1]:
        # 给今天赋予一个空值，后期填补至今天
        population_pool[datetime.date.today().strftime('%Y-%m-%d')] = np.nan

    population_pool_series = pd.Series(population_pool)
    population_pool_series.index = pd.DatetimeIndex(population_pool_series.index)

    # 获得每个交易日的信息
    # last_trade_date = w.tdays(flag, "2023-08-23", "Period=W", usedf=0).Data[0]
    # last_trade_date = timestamp[timestamp.index(flag): '2023-07-31']

    last_trade_date = [i for i in trade_date if i > datetime.datetime.strptime(flag[index_code], '%Y-%m-%d')]
    last_trade_date = [t.strftime('%Y-%m-%d') for t in last_trade_date]
    idx = population_pool_series.index
    idx = idx.append(pd.DatetimeIndex(last_trade_date))
    idx = idx.drop_duplicates()
    population_pool_series = population_pool_series.reindex(idx)
    population_pool_series = population_pool_series.sort_index()
    # 更改日期，填补空值
    population_pool_series = population_pool_series.ffill()
    last_trade_date_datetime = pd.DatetimeIndex(last_trade_date)
    # trade_month = [t.strftime('%Y-%m-%d') for t in last_trade_date]
    HindenburgIndex = Database_Hindenburg[index_code]
    for i in range(len(last_trade_date)):
        value_month = value.loc[population_pool_series[last_trade_date[i]]].query('日期 == "' +  last_trade_date[i]  +  '"')
        value_rank = value_month.rank(pct = True)
        # 处于行业前 30%
        fliter = value_rank[value_rank >= 0.7].dropna()
        # 样本池子
        sample_pool = fliter.index.droplevel(1)
        
        # sample_year_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] >= last_trade_date[i - 51]) & (data['日期'] <= last_trade_date[i])]
        sample_year_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] == last_trade_date[i])]
        # sample_month_data = data[(data['代码'].isin(sample_pool)) & (data['日期'] >= last_trade_date[i - 3]) & (data['日期'] <= last_trade_date[i])]

        sign1 = sample_year_data['12月最低'].values == sample_year_data['最低价(元)'].values
        NewLowNum = np.sum(sign1)
        # 可以对计算 max 的数据再次切片，剔除已经是 min 的标的
        sign2 = sample_year_data['12月最高'].values == sample_year_data['最高价(元)'].values
        NewHighNum = np.sum(sign2) - np.sum(sign1 & sign2)
        
        HindenburgIndex[last_trade_date_datetime[i]] = (NewHighNum - NewLowNum) / len(sample_pool)
        # print(i)

    # mkt = w.wsd(index_code, "close", flag, "2023-07-31", "Period=M;Fill=Previous", usedf=True)[1]
    # ax = HindenburgIndex.plot(figsize = (15, 7), color = 'silver')
    # ax1 = ax.twinx() 
    # mkt.plot(ax = ax1)
    # plt.legend(index_name.loc[index_code])

    # mkt = w.wsd(index_code, "close", last_trade_date[0], "2023-09-08", "Period=W;Fill=Previous", usedf=True)[1]
    # fig, ax = plt.subplots(figsize = (15, 7))
    # ax.fill_between(HindenburgIndex.index, 0, HindenburgIndex.values, facecolor = 'silver')
    # ax1 = ax.twinx() 
    # mkt.plot(ax = ax1)
    # ax.grid(axis = 'y', linestyle='--')
    # plt.legend(index_name.loc[index_code])

    # plt.savefig('./output/'+ str(index_name.loc[index_code].values[0]) + '.pdf')
    # plt.close()
    Database_Hindenburg_update[index_code] = HindenburgIndex
Database_Hindenburg_update.index = pd.DatetimeIndex(Database_Hindenburg_update.index)
for i in range(len(Database_Hindenburg_update)):
    if sum(Database_Hindenburg_update.iloc[i] > 0.8) >= 5:
        temp = Database_Hindenburg_update.iloc[i]
        temp[temp > 0.8] = 0
        Database_Hindenburg_update.iloc[i] = temp

for index_code in tqdm(index_list):

    mkt = w.wsd(index_code, "close", flag[index_code], "2023-09-15", "Period=W;Fill=Previous", usedf=True)[1]
    mkt = mkt[52:]
    fig, ax = plt.subplots(figsize = (15, 7))
    ax.fill_between(Database_Hindenburg_update[index_code].index, 0, Database_Hindenburg_update[index_code].values, facecolor = 'silver')
    ax1 = ax.twinx() 
    mkt.plot(ax = ax1)
    ax.grid(axis = 'y', linestyle='--')
    plt.legend(index_name.loc[index_code])

    plt.savefig('./output/'+ str(index_name.loc[index_code].values[0]) + '.pdf')
    plt.close()
# Out:
# ...
# 100%|██████████| 30/30 [00:20<00:00,  1.43it/s]
